# %%
import scripts.helpers as helpers
helpers.add_backend_to_path()

import os

from app.courses import CourseClient

courseClient = CourseClient(os.path.join("..", "web", "backend", "assets", "courses"))
courseClient.df.head()
# Out:
#                   CODE FACULTY  \
# CODE
# A_SPT            A_SPT     CST
# AUT_TM1        AUT_TM1     CST
# BELONG          BELONG     CST
# CJV_AJ_ESL  CJV_AJ_ESL     CST
# CJV_A_KPed  CJV_A_KPed     CST
#
#                                                       NAME_EN    LANGUAGE  \
# CODE
# A_SPT          English for court translators and interpreters     čeština
# AUT_TM1     Introduction to scheduling and time management...     čeština
# BELONG      Professional Writing and Communication with Em...  angličtina
# CJV_AJ_ESL                     English Speaking and Listening  angličtina
# CJV_A_KPed                 English for Department of Pedagogy     čeština
#
#                SEMESTER CREDITS DEPARTMENT  \
# CODE
# A_SPT         jaro 2025
# AUT_TM1     podzim 2024       1  Teiresiás
# BELONG        jaro 2025       3
# CJV_AJ_ESL    jaro 2025       2
# CJV_A_KPed  podzim 2024
#
#                                                      TEACHERS COMPLETION  \
# CODE
# ...

# %%
course_names = courseClient.df["NAME_EN"]

course_names_list = course_names.tolist()

# write the list to a file separated by new lines
with open("data/course_names.txt", "w") as f:
    for course_name in course_names_list:
        f.write(course_name + "\n")

# %%
people = [
  {
    "name": "Aneta Nováková",
    "studies": "Applied Informatics",
    "interests": [
      "Machine learning",
      "Data analysis",
      "Programming",
      "Cybersecurity"
    ],
    "liked_courses": [
      "Introduction to Machine Learning",
      "Data – the Answer to the Ultimate Question of Life, the Universe, and Everything...",
      "Applied Cryptography",
      "Programming in Python",
      "Big Data with SQL"
    ],
    "disliked_courses": [
      "Introduction to Archaeology",
      "History of Medieval Europe: Selected Chapters",
      "Introduction to the Study of Religions"
    ]
  },
  {
    "name": "Jakub Svoboda",
    "studies": "Political Science and International Relations",
    "interests": [
      "European Union politics",
      "International security",
      "Political philosophy",
      "History"
    ],
    "liked_courses": [
      "European Union Public Policy",
      "International Security: Practical Insights",
      "Introduction to Political Science",
      "History of Economic Theories 1",
      "The economic crises of capitalism"
    ],
    "disliked_courses": [
      "Anatomy I",
      "Organic Chemistry",
      "Principles of Microbiology for Cosmetic Purposes"
    ]
  },
  {
    "name": "Ema Horáková",
    "studies": "English Language and Literature",
    "interests": [
      "Modern literature",
      "Linguistics",
      "Translation",
      "Cultural studies"
    ],
    "liked_courses": [
      "Modern Anglophone Poetry 1900-2016",
      "Introduction to Linguistics",
      "Literary Translation of Short Stories",
      "Contemporary British Women Novelists",
      "Text and Discourse Analysis"
    ],
    "disliked_courses": [
      "Financial Accounting 1",
      "Applied Statistics 1",
      "Introduction to SQL"
    ]
  },
  {
    "name": "Matěj Beneš",
    "studies": "Law and Legal Science",
    "interests": [
      "International law",
      "Human rights",
      "Criminal law",
      "Legal history"
    ],
    "liked_courses": [
      "International Law and Human Rights",
      "Criminality and Social Work with Offenders",
      "Introduction to Law",
      "Czech Legal History of the Middle Ages",
      "Forensic Medicine - practice"
    ],
    "disliked_courses": [
      "History of Rock music",
      "Applied Genetics",
      "Introduction to Musicology"
    ]
  },
  {
    "name": "Sofia Krajčíková",
    "studies": "Psychology",
    "interests": [
      "Developmental psychology",
      "Social psychology",
      "Clinical psychology",
      "Neuroscience"
    ],
    "liked_courses": [
      "Developmental Psychology I",
      "Social Psychology I",
      "Introduction to Clinical Psychology",
      "Introduction to Neuroscience",
      "Psychological and Social Skill Development Groups"
    ],
    "disliked_courses": [
      "Introduction to Medieval Latin",
      "Chronology and Metrology",
      "Introduction to the Study of Archaeology"
    ]
  },
  {
    "name": "Adam Kovář",
    "studies": "Economics and Management",
    "interests": [
      "Microeconomics",
      "Macroeconomics",
      "Financial markets",
      "Strategic management"
    ],
    "liked_courses": [
      "Microeconomics 1",
      "Macroeconomics 1",
      "Financial Markets",
      "Strategic Management",
      "Managerial Accounting"
    ],
    "disliked_courses": [
      "Introduction to Musicology",
      "History of Art History",
      "Biblical Archaeology"
    ]
  },
  {
    "name": "Tereza Kučerová",
    "studies": "Sociology and Social Policy",
    "interests": [
      "Social stratification",
      "Migration",
      "Cultural sociology",
      "Public policy"
    ],
    "liked_courses": [
      "Social Stratification and Labour Market",
      "Contemporary Migration Research",
      "Introduction to Cultural Sociology",
      "Public Policy Process",
      "Sociology of Education"
    ],
    "disliked_courses": [
      "Optics and optometry II-practice",
      "Oral Surgery I - practice",
      "General and Inorganic Chemistry"
    ]
  },
  {
    "name": "Lukáš Veselý",
    "studies": "History",
    "interests": [
      "Medieval history",
      "Auxiliary historical sciences",
      "History of Central Europe",
      "Historical sources"
    ],
    "liked_courses": [
      "Medieval History of the Czech Land",
      "Auxiliary Historical Sciences",
      "Historical Sources and their Interpretation",
      "Latin Script and Book Culture in the Middle Ages I (800-1200)",
      "Introduction to Diplomatics"
    ],
    "disliked_courses": [
      "Applied Statistics 1",
      "Biochemistry - lecture",
      "Organic Chemistry Seminar"
    ]
  },
  {
    "name": "Karolína Fischerová",
    "studies": "Chemistry",
    "interests": [
      "Organic chemistry",
      "Biochemistry",
      "Analytical chemistry",
      "Environmental chemistry"
    ],
    "liked_courses": [
      "Organic Chemistry",
      "Biochemistry",
      "Analytical Chemistry I",
      "Environmental Chemistry",
      "Modern Methods of Extraction and Identification of Natural Compounds"
    ],
    "disliked_courses": [
      "History of World Cinema I",
      "Film Style Analysis",
      "Introduction to Theatre Studies"
    ]
  },
  {
    "name": "Martin Král",
    "studies": "Physics",
    "interests": [
      "Theoretical physics",
      "Astrophysics",
      "Quantum mechanics",
      "Mathematical physics"
    ],
    "liked_courses": [
      "Theoretical mechanics",
      "Introduction to Quantum Computing",
      "Mathematical Foundations of Computer Science",
      "General astronomy",
      "Physics in alive nature"
    ],
    "disliked_courses": [
      "Czech for Foreigners 1",
      "Oral Hygiene I - practice",
      "Introduction to Museology and Museography"
    ]
  },
  {
    "name": "Petra Zemanová",
    "studies": "Biology",
    "interests": [
      "Molecular biology",
      "Genetics",
      "Botany",
      "Ecology"
    ],
    "liked_courses": [
      "Molecular Biology",
      "Applied Genetics",
      "Botany I",
      "General Ecology and Ecology of Human Health",
      "Methods of Molecular Biology"
    ],
    "disliked_courses": [
      "Managerial Psychology",
      "Business Basics",
      "Project management"
    ]
  },
  {
    "name": "Tomáš Růžička",
    "studies": "Geography",
    "interests": [
      "Physical geography",
      "GIS",
      "Cartography",
      "Environmental geography"
    ],
    "liked_courses": [
      "Physical geography",
      "Geographic information systems in archaeology",
      "Cartography",
      "Environmental geography",
      "Applied Geoinformatics"
    ],
    "disliked_courses": [
      "History of the Ancient Near East I",
      "Reading and Interpretation of Historical Sources - Near East",
      "Introduction to the Study of Ancient History"
    ]
  },
  {
    "name": "Veronika Dvořáková",
    "studies": "Art History",
    "interests": [
      "Medieval art",
      "Modern art",
      "Architecture",
      "Curatorship"
    ],
    "liked_courses": [
      "Medieval Art: From Constantine to Giotto I",
      "The Art of the Contemporary World",
      "An Introduction to the History of the Architecture",
      "Curatorship in practice I",
      "Seminar: Architecture in Brno"
    ],
    "disliked_courses": [
      "Introduction to Econometrics",
      "Banking I",
      "Financial Mathematics"
    ]
  },
  {
    "name": "Jan Novotný",
    "studies": "Informatics (Software Engineering)",
    "interests": [
      "Software development",
      "Algorithms",
      "Data structures",
      "Programming languages"
    ],
    "liked_courses": [
      "Algorithms and data structures I",
      "Introduction to Programming and Algorithms",
      "Principles of Programming Languages",
      "Software Engineering I",
      "Programming in Python"
    ],
    "disliked_courses": [
      "Music History in Outline I",
      "Introduction to Organology",
      "Harmony"
    ]
  },
  {
    "name": "Kristína Nagyová",
    "studies": "Czech Language and Literature (Teaching)",
    "interests": [
      "Czech grammar",
      "Stylistics",
      "Literature for children",
      "Teaching methods"
    ],
    "liked_courses": [
      "Modern Czech Grammar",
      "Stylistics - Lecture",
      "Children Literature I",
      "Didactics of Czech Language and Literature II",
      "Language Culture and Rhetoric"
    ],
    "disliked_courses": [
      "Introduction to Quantum Computing",
      "Mathematical Foundations of Computer Science",
      "Linear algebra and discrete mathematics"
    ]
  },
  {
    "name": "Peter Horváth",
    "studies": "Security and Strategic Studies",
    "interests": [
      "International security",
      "Terrorism",
      "Cyber warfare",
      "Crisis management"
    ],
    "liked_courses": [
      "International Security Policy",
      "Terrorism",
      "Cyber Warfare",
      "Crisis Management",
      "Threats and Risks of the Present World"
    ],
    "disliked_courses": [
      "History of Italian Literature I (from the Origins to Dante)",
      "Practical Italian I",
      "Italian History and Culture I"
    ]
  },
  {
    "name": "Veronika Kováčová",
    "studies": "Social Work",
    "interests": [
      "Social work with families and children",
      "Minorities",
      "Social policy",
      "Therapy"
    ],
    "liked_courses": [
      "Social Work with Children and Families",
      "Minorities",
      "Social Policy",
      "Working with Families - systemic and dialogic perspectives",
      "Family Social Work with Endangered Children and Families"
    ],
    "disliked_courses": [
      "Introduction to Biomechanics",
      "Exercise Physiology",
      "Sports Traumatology"
    ]
  },
  {
    "name": "Michal urban",
    "studies": "Philosophy",
    "interests": [
      "History of philosophy",
      "Ethics",
      "Political philosophy",
      "Logic"
    ],
    "liked_courses": [
      "History of Philosophy I",
      "Ethics",
      "Social and Political Philosophy",
      "Introduction to Philosophy",
      "Elements of Logic and Critical Thinking"
    ],
    "disliked_courses": [
      "Introduction to Genetics",
      "Molecular Biology",
      "Cell biology and genetics - seminar"
    ]
  },
  {
    "name": "Simona Poláková",
    "studies": "Translation and Interpreting (English)",
    "interests": [
      "Literary translation",
      "Specialized translation (legal)",
      "Interpreting",
      "English linguistics"
    ],
    "liked_courses": [
      "Literary Translation of Short Stories",
      "Legal Translation",
      "Simultaneous interpreting",
      "Stylistics for English-language Translation",
      "Specialized translation"
    ],
    "disliked_courses": [
      "Histopathological Techniques I",
      "Clinical Biochemistry I - practice",
      "Medical Oral Microbiology I - practice"
    ]
  },
  {
    "name": "Filip Blažek",
    "studies": "Journalism and Media Studies",
    "interests": [
      "Audiovisual journalism",
      "Online media",
      "Media ethics",
      "Political communication"
    ],
    "liked_courses": [
      "Audiovisual journalism",
      "Online journalism",
      "Journalism ethics and regulation",
      "Political communication",
      "Video journalism"
    ],
    "disliked_courses": [
      "Econometrics",
      "Mathematical Geology",
      "Modeling methods in petrology and mineralogy"
    ]
  },
  {
    "name": "Barbora Kohoutová",
    "studies": "Archaeology",
    "interests": [
      "Prehistory",
      "Medieval archaeology",
      "Archaeological methods",
      "Material culture"
    ],
    "liked_courses": [
      "Introduction to the Study of Archaeology",
      "Archaeological Method and Theory",
      "Material Culture of the Stone Age",
      "Medieval material culture",
      "Practical training in archaeological excavation I (Těšetice-Kyjovice)"
    ],
    "disliked_courses": [
      "Genetics in Dentistry - practice",
      "Pharmacology I - practice",
      "Histology and Embryology I - practice"
    ]
  },
  {
    "name": "Ondřej Čevelík",
    "studies": "Musicology",
    "interests": [
      "History of music",
      "Music theory",
      "Music analysis",
      "Ethnomusicology"
    ],
    "liked_courses": [
      "History of Music Theory",
      "Music theory",
      "Music Analysis",
      "Seminar Ethnomusicology I",
      "Harmony"
    ],
    "disliked_courses": [
      "Cyber Warfare",
      "Threats and Risks of the Present World",
      "Criminology"
    ]
  },
  {
    "name": "Kristýna Veselá",
    "studies": "International Regional Studies (European Studies)",
    "interests": [
      "European integration",
      "EU policies",
      "International organizations",
      "European history"
    ],
    "liked_courses": [
      "European Integration",
      "EU Policies",
      "International Organizations and Diplomacy",
      "European Union in European Politics since 1989",
      "History of International Relations and World Politics"
    ],
    "disliked_courses": [
      "Medical Microbiology I - practice",
      "Pathology I - practice",
      "General and Inorganic Chemistry"
    ]
  },
  {
    "name": "Adam Jelínek",
    "studies": "Physiotherapy",
    "interests": [
      "Kinesiology",
      "Rehabilitation",
      "Sports physiotherapy",
      "Anatomy"
    ],
    "liked_courses": [
      "Kinesiology, Algesiology and Derived Techniques of Diagnostics and Therapy 1",
      "Propedeutics in rehabilitation and basics of physiotherapy I",
      "Anatomy I",
      "Sports physiotherapy 2",
      "Practice II"
    ],
    "disliked_courses": [
      "Czech Language for Foreigners I",
      "Hungarian I.",
      "Spanish for Beginners I"
    ]
  },
  {
    "name": "Natália Kováčiková",
    "studies": "Nutritional Therapy",
    "interests": [
      "Clinical nutrition",
      "Dietetics",
      "Food chemistry",
      "Public health"
    ],
    "liked_courses": [
      "Clinical Nutrition and Dietetics I - practice",
      "Nutrition therapy I - lecture",
      "Food Chemistry I - practice",
      "Public Health",
      "Basics of Human Nutrition"
    ],
    "disliked_courses": [
      "Latin Script and Book Culture in the Middle Ages I (800-1200)",
      "Introduction to Diplomatics",
      "Medieval Diplomatics"
    ]
  },
  {
    "name": "Samuel Kráľ",
    "studies": "General Medicine",
    "interests": [
      "Surgery",
      "Internal medicine",
      "Anatomy",
      "Emergency medicine"
    ],
    "liked_courses": [
      "Surgery I - practice",
      "Internal Medicine",
      "Anatomy I - dissection",
      "Emergency Skills Training",
      "Vacational Training in Surgery and Internal Medicine"
    ],
    "disliked_courses": [
      "Classical Greek I",
      "Reading Xenophon",
      "Introduction to Classical Philology I"
    ]
  },
  {
    "name": "Ema Fialová",
    "studies": "Dentistry",
    "interests": [
      "Restorative dentistry",
      "Oral surgery",
      "Periodontology",
      "Preventive dentistry"
    ],
    "liked_courses": [
      "Restorative Dentistry I - practice",
      "Oral Surgery I - practice",
      "Periodontology I - practice",
      "Preventive Dentistry - practice",
      "Vacational Training in Practical Dentistry 1"
    ],
    "disliked_courses": [
      "History of Japanese Thought",
      "Japanese Literature",
      "Introduction to Chinese Studies"
    ]
  },
  {
    "name": "Filip Lukáč",
    "studies": "Sports Studies (Coaching)",
    "interests": [
      "Football coaching",
      "Sports training",
      "Sports psychology",
      "Sports management"
    ],
    "liked_courses": [
      "Football coach UEFA A 1",
      "Theory of Sports Training",
      "Sports Psychology and Coaching",
      "Sports Management",
      "Coaching Practice 1"
    ],
    "disliked_courses": [
      "Analytical Chemistry I",
      "Organic Chemistry",
      "Biochemistry - lecture"
    ]
  },
  {
    "name": "Laura Gašparovičová",
    "studies": "Arts Management",
    "interests": [
      "Cultural economics",
      "Festival organization",
      "Marketing in culture",
      "Museum studies"
    ],
    "liked_courses": [
      "Chapters from the history of cultural economics and cultural institutions",
      "Festival organization in theory and practice",
      "Museum Marketing and Management",
      "Introduction to Museology and Museography",
      "Marketing in the non-profit sector"
    ],
    "disliked_courses": [
      "Introduction to Econometrics",
      "Time Series",
      "Quantitative Methods for Decision Making"
    ]
  },
  {
    "name": "Adam Benešovský",
    "studies": "Polish Studies",
    "interests": [
      "Polish language",
      "Literature",
      "Culture",
      "Contemporary Poland",
      "Translation"
    ],
    "liked_courses": [
      "Course of Polish Language I",
      "Polish Literature and Culture of the 20th Century",
      "Contemporary Poland: Development, Current Condition & Outlooks",
      "Translation Seminar I",
      "Cultural Tourism in Southern Poland"
    ],
    "disliked_courses": [
      "Introduction to Quantum Computing",
      "Relief and Structure of the Earth",
      "Mineralogy"
    ]
  },
  {
    "name": "Kristína Králová",
    "studies": "Aesthetics",
    "interests": [
      "Philosophy of art",
      "History of aesthetics",
      "Theory of art",
      "Contemporary aesthetics"
    ],
    "liked_courses": [
      "Philosophy of Art and Beauty",
      "History of Aesthetics I",
      "Theory of Art and its Terminology",
      "The Selected Topics of Contemporary Aesthetics",
      "Introduction into Aesthetics and General Theory of Art"
    ],
    "disliked_courses": [
      "Financial Accounting 1",
      "Tax evidence",
      "Business law"
    ]
  },
  {
    "name": "Tomáš Rys",
    "studies": "Informatics (Cybersecurity)",
    "interests": [
      "Cybersecurity",
      "Network security",
      "Ethical hacking",
      "Digital forensics"
    ],
    "liked_courses": [
      "Cybersecurity Operations",
      "Secure Network Design",
      "Digital Forensics",
      "Network Forensics",
      "Introduction to IT Security"
    ],
    "disliked_courses": [
      "Introduction to Music Education",
      "History of Music 1",
      "Harmony"
    ]
  },
  {
    "name": "Natália Kováčová",
    "studies": "Environmental Studies",
    "interests": [
      "Environmental ethics",
      "Ecology",
      "Sustainable development",
      "Climate change",
      "Environmental history"
    ],
    "liked_courses": [
      "Environmental Ethics I",
      "General Ecology and Landscape Ecology",
      "Sustainable Development",
      "Climatic change and possible solutions",
      "Environmental History"
    ],
    "disliked_courses": [
      "History of the Ancient Near East I",
      "Reading and Interpretation of Historical Sources - Near East",
      "Introduction to the Study of Ancient History"
    ]
  },
  {
    "name": "Adam Fiala",
    "studies": "Quantitative Analysis in Social Sciences",
    "interests": [
      "Statistics",
      "Data analysis",
      "Research methodology",
      "Social science research"
    ],
    "liked_courses": [
      "Statistics I",
      "Quantitative Research",
      "Statistical Data Analysis with SPSS",
      "Research Methodology in Sociology",
      "Applied Statistics 1"
    ],
    "disliked_courses": [
      "Ancient Greek I",
      "Reading Xenophon",
      "Introduction to Classical Philology I"
    ]
  },
  {
    "name": "Kristína Lukešová",
    "studies": "Information Science and Librarianship",
    "interests": [
      "Digital literacy",
      "Information retrieval",
      "Library systems",
      "Cultural heritage digitization"
    ],
    "liked_courses": [
      "Digital Literacy",
      "Information Services and Retrieval",
      "Library Systems and Standards",
      "Cultural Heritage Digitization",
      "Information Retrieval"
    ],
    "disliked_courses": [
      "Organic Chemistry",
      "Biochemistry - lecture",
      "Analytical Chemistry I"
    ]
  },
  {
    "name": "Peter Novák",
    "studies": "Japanese Studies",
    "interests": [
      "Japanese language",
      "Culture",
      "Literature",
      "History",
      "Contemporary Japan"
    ],
    "liked_courses": [
      "Japanese Language I",
      "History of Japan",
      "Japanese literature",
      "Japanese Culture in Film",
      "Japanese conversation practice"
    ],
    "disliked_courses": [
      "Law in Medicine",
      "Forensic Medicine - practice",
      "Medical Psychology and Psychosomatics"
    ]
  },
  {
    "name": "Veronika Benková",
    "studies": "Balkan, Eurasian and Central European Studies",
    "interests": [
      "History and culture of the Balkans",
      "South Slavonic languages",
      "Contemporary Balkan politics"
    ],
    "liked_courses": [
      "History and Culture of the Balkans in the Ottoman Era",
      "Contemporary Serbia",
      "South Slavic Literature of the 20th Century",
      "Introduction to South Slavonic Languages Issues",
      "Past and Present of Balkan's Ethnics"
    ],
    "disliked_courses": [
      "Econometrics",
      "Financial Markets",
      "Banking I"
    ]
  },
  {
    "name": "Michal Hudák",
    "studies": "Scandinavian Studies (Norwegian)",
    "interests": [
      "Norwegian language",
      "Literature",
      "Scandinavian culture and society",
      "Translation"
    ],
    "liked_courses": [
      "Norwegian",
      "Introduction to Scandinavian Studies",
      "History of Norwegian Literature I",
      "Scandinavia on the move - society and culture",
      "Translation: Selected Topics"
    ],
    "disliked_courses": [
      "Anatomy I",
      "Physiology I - lecture",
      "Medical Biology I - practice"
    ]
  },
  {
    "name": "Simona Vašková",
    "studies": "Spanish Language and Literature",
    "interests": [
      "Spanish language",
      "Latin American literature",
      "Spanish culture",
      "Translation"
    ],
    "liked_courses": [
      "Practical Spanish I",
      "Latin American Literature I",
      "History and Culture of Spanish-Speaking Countries I",
      "Translation seminar",
      "Spanish Literature in Czech Translations"
    ],
    "disliked_courses": [
      "Introduction to Musicology",
      "Harmony",
      "Counterpoint"
    ]
  },
  {
    "name": "Filip Molnár",
    "studies": "Italian Language and Literature",
    "interests": [
      "Italian language",
      "Literature",
      "Culture",
      "History",
      "Translation"
    ],
    "liked_courses": [
      "Practical Italian I",
      "Italian Literature I",
      "Italian History and Culture I",
      "Conversation in Italian",
      "Translation seminar"
    ],
    "disliked_courses": [
      "Applied Statistics 1",
      "Econometrics",
      "Quantitative Methods for Decision Making"
    ]
  },
  {
    "name": "Barbora Němcová",
    "studies": "French Language and Literature",
    "interests": [
      "French language",
      "Literature",
      "Culture",
      "History",
      "Translation"
    ],
    "liked_courses": [
      "Practical French I",
      "French Literature I",
      "French History and Culture I",
      "Translation Seminar I",
      "French Phonetics and Phonology"
    ],
    "disliked_courses": [
      "Introduction to Archaeology",
      "History of the Ancient Near East I",
      "Biblical Archaeology"
    ]
  },
  {
    "name": "Ondřej Soukup",
    "studies": "Czech Language and Literature (Literature focus)",
    "interests": [
      "Czech literature (19th-21st century)",
      "Literary theory",
      "World literature",
      "Creative writing"
    ],
    "liked_courses": [
      "Czech Literature of the 19th Century I",
      "Czech Contemporary Literature",
      "Theory of Literature",
      "Selected works of world literature to 1800",
      "Creative Writing"
    ],
    "disliked_courses": [
      "Biochemistry - lecture",
      "Organic Chemistry",
      "General and Inorganic Chemistry"
    ]
  },
  {
    "name": "Kristýna Tichá",
    "studies": "Russian Language and Literature",
    "interests": [
      "Russian language",
      "Literature",
      "Culture",
      "History",
      "Translation"
    ],
    "liked_courses": [
      "Speaking and Writing in Russian I",
      "An Overview of Russian Literature I",
      "History of Russia",
      "Russian Cultural Space",
      "Translation of Non-Literary Texts"
    ],
    "disliked_courses": [
      "Anatomy I",
      "Physiology I - lecture",
      "Medical Biology I - practice"
    ]
  },
  {
    "name": "Samuel Veselý",
    "studies": "Physical Education and Sport (Teaching)",
    "interests": [
      "Teaching physical education",
      "Sport pedagogy",
      "Sports training",
      "Specific sports (e.g., basketball, volleyball)"
    ],
    "liked_courses": [
      "Didactics of Physical Education",
      "Theory of Sports Training",
      "Theory and Didactics of Basketball and Volleyball",
      "Sport Pedagogy",
      "Teaching Practice I"
    ],
    "disliked_courses": [
      "Calculus of variations and its applications",
      "Introduction to Quantum Mechanics",
      "Theoretical mechanics"
    ]
  },
  {
    "name": "Natália Králová",
    "studies": "Applied Linguistics",
    "interests": [
      "Language acquisition",
      "Sociolinguistics",
      "Corpus linguistics",
      "Language testing"
    ],
    "liked_courses": [
      "Applied Linguistics: Language Acquisition",
      "Introduction to Sociolinguistics",
      "Introduction to Corpus Linguistics",
      "Language Testing",
      "Text and Discourse Analysis"
    ],
    "disliked_courses": [
      "Principles of Economics",
      "Financial Accounting",
      "Management"
    ]
  },
  {
    "name": "Adam Urban",
    "studies": "General Theory and History of Art and Culture (Museology)",
    "interests": [
      "Museology",
      "Cultural heritage",
      "Exhibition making",
      "Material culture"
    ],
    "liked_courses": [
      "Introduction to Museology and Museography",
      "Cultural Heritage Digitization",
      "Exhibition Making Practice",
      "Museum Collections Practice",
      "Material culture of the traditional countryside I"
    ],
    "disliked_courses": [
      "Introduction to Programming and Algorithms",
      "Object-oriented Methods for Design of Information Systems",
      "Database systems"
    ]
  },
  {
    "name": "Kristína Blažková",
    "studies": "Ethnology",
    "interests": [
      "Folkloristics",
      "Material culture",
      "Social anthropology",
      "Cultural heritage preservation"
    ],
    "liked_courses": [
      "Introduction to Folkloristics",
      "Material culture of the traditional countryside I",
      "Introduction to Ethnology",
      "Preservation of the Cultural Heritage I",
      "Study of Sources and Field Research"
    ],
    "disliked_courses": [
      "Numerical Methods",
      "Linear algebra and discrete mathematics",
      "Applied math analysis"
    ]
  },
  {
    "name": "Peter Horváth",
    "studies": "Classical Archaeology",
    "interests": [
      "Greek art",
      "Roman architecture",
      "Aegean prehistory",
      "Archaeological methods"
    ],
    "liked_courses": [
      "Greek Art I",
      "Roman Architecture and Urbanism from an Archaeological Perspective",
      "Aegean prehistory",
      "Actual objectives, theory and methods of classical archaeology",
      "Summer Praxis in Archeology for Classical archaeology - maior"
    ],
    "disliked_courses": [
      "Principles of Economics",
      "Management",
      "Marketing"
    ]
  },
  {
    "name": "Veronika Lukešová",
    "studies": "Religious Studies",
    "interests": [
      "Buddhism",
      "Ancient religions",
      "Religious history",
      "Methodology of religious studies"
    ],
    "liked_courses": [
      "Buddhism I",
      "Religions of the Ancient Mediterranean and Near East",
      "Introduction to Research Methodology in the Study of Religions",
      "Religion in Historical and Comparative Perspectives",
      "History of the Study of Religions"
    ],
    "disliked_courses": [
      "C++ Programming",
      "Java",
      "Introduction to DB and IS"
    ]
  },
  {
    "name": "Michal Gašparovič",
    "studies": "Interactive Media Studies",
    "interests": [
      "New media art",
      "Digital culture",
      "Game studies",
      "Interactive art",
      "Visual culture"
    ],
    "liked_courses": [
      "New Media Art I",
      "Digital Games Critical Analyses",
      "Visual Culture",
      "Introduction to Interactive Media Studies I",
      "Game Studies"
    ],
    "disliked_courses": [
      "Biochemistry - lecture",
      "Organic Chemistry",
      "Analytical Chemistry I"
    ]
  }
]

# %%
# print the names of the people, their studies, and their interests, liked courses, and disliked courses
def print_person_info(person):
    print(f"Name: {person['name']}")
    print(f"Studies: {person['studies']}")
    print(f"Interests: {', '.join(person['interests'])}")
    for liked_course in person['liked_courses']:
        if liked_course in course_names_list:
            print(f"Liked course: {liked_course}")
        else:
            print(f"Liked course: {liked_course} (not found in course names)")
    for disliked_course in person['disliked_courses']:
        if disliked_course in course_names_list:
            print(f"Disliked course: {disliked_course}")
        else:
            print(f"Disliked course: {disliked_course} (not found in course names)")
    print()

for person in people[:1]:
    pass
    print_person_info(person)
# Out:
# Name: Aneta Nováková
# Studies: Applied Informatics
# Interests: Machine learning, Data analysis, Programming, Cybersecurity
# Liked course: Introduction to Machine Learning
# Liked course: Data – the Answer to the Ultimate Question of Life, the Universe, and Everything...
# Liked course: Applied Cryptography
# Liked course: Programming in Python
# Liked course: Big Data with SQL
# Disliked course: Introduction to Archaeology (not found in course names)
# Disliked course: History of Medieval Europe: Selected Chapters
# Disliked course: Introduction to the Study of Religions

# %%
# Add liked_courses_codes and disliked_courses_codes keys to each person
import pandas as pd

# Get the course names and codes from the courseClient dataframe
course_df = courseClient.df[["NAME_EN", "CODE"]]
course_dict = dict(zip(course_df["NAME_EN"], course_df["CODE"]))

# Function to find course codes based on course names
def find_course_codes(course_names):
    codes = []
    for course_name in course_names:
        if course_name in course_dict:
            codes.append(course_dict[course_name])
        else:
            # If exact match not found, try to find a close match
            for db_course_name in course_dict.keys():
                if course_name.lower() in db_course_name.lower() or db_course_name.lower() in course_name.lower():
                    codes.append(course_dict[db_course_name])
                    break
            else:
                print(f"Course '{course_name}' not found in course names.")
                codes.append(None)  # No match found
    return codes

# Add codes to each person
for person in people:
    person["liked_courses_codes"] = find_course_codes(person["liked_courses"])
    person["disliked_courses_codes"] = find_course_codes(person["disliked_courses"])

# %%
from main import recommendations, startup_event, log_recommendation_feedback

await startup_event("../web/backend/assets")

# for person in people:
#     liked = person["liked_courses_codes"]
#     disliked = person["disliked_courses_codes"]
#     model = "embeddings_mmr"
#     relevance = 0.8

#     # Get recommendations
#     recommended = await recommendations(liked, disliked, [], 1, model, relevance=0.8)
#     print(f"Recommendations for {person['name']}:")
#     print(recommended)
# Out:
# 2025-05-05 19:42:19,678 - muni_courses - INFO - Logger initialized at 2025-05-05T19:42:19.678988
# 2025-05-05 19:42:19,678 - muni_courses - INFO - Starting Muni Courses API
# 2025-05-05 19:42:19,737 - muni_courses - INFO - Loading course data...
# 2025-05-05 19:42:19,767 - muni_courses - INFO - Loading embeddings...
# 2025-05-05 19:42:19,769 - muni_courses - INFO - Loading Gemini keyword intersections...
# 2025-05-05 19:42:19,769 - muni_courses - INFO - Loading TF-IDF keyword intersections...
# 2025-05-05 19:42:19,774 - muni_courses - INFO - Initializing MongoDB logger...
# 2025-05-05 19:42:19,840 - muni_courses - INFO - Embeddings loaded successfully with shape (21106, 768)
# 2025-05-05 19:42:20,119 - muni_courses - INFO - Course data loaded successfully with 21106 courses
# 2025-05-05 19:42:21,668 - muni_courses - INFO - Successfully connected to MongoDB Atlas
# 2025-05-05 19:42:21,668 - muni_courses - INFO - MongoDB logger initialized successfully
# ...

# %%
result = await recommendations(
    liked=["PB007", "IB111", "IB031"],
    disliked=[],
    skipped=[],
    n=1,
    model="keywords_tfidf",
    relevance=42
)
result
# Out:
# RecommendationResponse(recommended_courses=[CourseWithId(CODE='AI002', FACULTY='FF', NAME=' Building AI ', NAME_EN='Building AI', LANGUAGE='angličtina', SEMESTER='podzim 2024', CREDITS='2', DEPARTMENT='KISK', TEACHERS='Škyřík, P. - Švidrnochová, K.', COMPLETION='z', PREREQUISITES='', FIELDS_OF_STUDY='FNISKkJ, FBISKpH, FNISKpV, FBDISdJ, FBISKkH, FNISKpH, FBISKkJ, FBISKpJ, FNISKpJ, FNISKkH, FBISKpV', TYPE_OF_STUDY='bakalářský, magisterský navazující', LECTURES_SEMINARS_HOMEWORK='0/0/0', SYLLABUS='Building AI is a flexible online course for anyone who wants to learn about the practical methods that make artificial intelligence a reality. You will get a solid introduction to for example machine learning and neural networks, and you will learn where and how AI methods are applied in real life. It is easy to move freely between the three difficulty levels, from multiple choice exercises to programming with Python – depending on whether you know programming or not. As a result of this cours
# ...

# %%
from google import genai
from google.genai import types
import json

from dotenv import load_dotenv
load_dotenv()

# Initialize the client
client = genai.Client(
    api_key=os.getenv("GEMINI_API_KEY"),
)

def prompt_gemini(input) -> str:
    model = "gemini-2.0-flash"

    generate_content_config = types.GenerateContentConfig(
        temperature=1,
        top_p=0.95,
        top_k=40,
        max_output_tokens=8192,
        safety_settings=[
            types.SafetySetting(
                category="HARM_CATEGORY_HARASSMENT",
                threshold="BLOCK_NONE",  # Block none
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_HATE_SPEECH",
                threshold="BLOCK_NONE",  # Block none
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_SEXUALLY_EXPLICIT",
                threshold="BLOCK_NONE",  # Block none
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_DANGEROUS_CONTENT",
                threshold="BLOCK_NONE",  # Block none
            ),
            types.SafetySetting(
                category="HARM_CATEGORY_CIVIC_INTEGRITY",
                threshold="BLOCK_LOW_AND_ABOVE",  # Block most
            ),
        ],
        response_mime_type="application/json",
        response_schema=genai.types.Schema(
            type = genai.types.Type.OBJECT,
            enum = [],
            required = ["like"],
            properties = {
                "like": genai.types.Schema(
                    type = genai.types.Type.BOOLEAN,
                )
            },
        ),
        system_instruction=[
            types.Part.from_text(text="""You are a university student. You'll be given this information:
- Your interests
- Your field of study
- List of courses you liked
- List of courses you disliked

You will be given a course name and description and you will have to decide if you like it or not. You will answer with "like" if you like the course and "dislike" if you don't like it.
You should be conservative about youre like, only like those that match you interests, hobbies and field of study. If you are not sure, answer with "dislike". 

Be VERY PICKY. The course must match your interests very closely. DO NOT like courses that ore only slightly related to your field of study!
"""),
        ],
    )

    contents = [
        types.Content(
            role="user",
            parts=[types.Part.from_text(text=str(input))],
        ),
    ]

    # Collect the response text from streaming
    response_text = ""
    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        response_text += chunk.text

    return response_text

# %%
from main import db, models

async def test_person_model(person, model="embeddings_mmr"):
    relevance = 0.8
    initial_liked = person["liked_courses"].copy()
    initial_disliked = person["disliked_courses"].copy()  
    for i in range(15):
        print(f"Test {i+1} for {person['name']}")
        interests = ", ".join(person["interests"])
        studies = person["studies"]

        recommended_course = await recommendations(person["liked_courses_codes"], person["disliked_courses_codes"], [], 1, model, relevance=relevance)
        recommended_course = recommended_course.recommended_courses[0]
        recommended_course_name = recommended_course.NAME_EN
        input = f"""
Interests: {interests}
Studies: {studies}
Liked courses: {initial_liked}
Disliked courses: {initial_disliked}

Course to rate: {recommended_course_name}
Couse description: {recommended_course.DESCRIPTION}
    """
        response = prompt_gemini(input)
        response_parsed = json.loads(response)
        liked = response_parsed["like"]
        print(f"Response: {liked} for course {recommended_course_name}")
        
        db.log_bot_recommendation_feedback(
            liked=person["liked_courses_codes"],
            disliked=person["disliked_courses_codes"],
            skipped=[],
            course=recommended_course.CODE,
            action="like" if liked else "dislike",
            user_id=person["name"],
            model=model,
        )
        
        # add the recommended course to liked or disliked courses
        if liked:
            person["liked_courses"].append(recommended_course_name)
            person["liked_courses_codes"].append(recommended_course.CODE)
            relevance = max(relevance * 0.9, 0.01)
        else:
            person["disliked_courses"].append(recommended_course_name)
            person["disliked_courses_codes"].append(recommended_course.CODE)
            relevance = min(relevance + (1-relevance) * 0.1, 0.99)


# for person in people:
#     for model in await models():
#         await test_person_model(person, model=model)

# %%
import concurrent.futures
import threading
import asyncio

# Function to run tests for a batch of people
async def test_batch_of_people(batch_people):
    for person in batch_people:
        for model_name in await models():
            await test_person_model(person, model=model_name)
    return f"Completed batch with {len(batch_people)} people"

# Function to create a new event loop and run the async function
def run_in_thread(batch_people):
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)
    return loop.run_until_complete(test_batch_of_people(batch_people))

# Divide people into batches of 10
def create_batches(people_list, batch_size=10):
    return [people_list[i:i + batch_size] for i in range(0, len(people_list), batch_size)]

# Run the tests in parallel using ThreadPoolExecutor
def run_parallel_tests(people_list, max_workers=None):
    batches = create_batches(people_list)
    print(f"Created {len(batches)} batches of people")
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(run_in_thread, batch) for batch in batches]
        
        for future in concurrent.futures.as_completed(futures):
            try:
                result = future.result()
                print(result)
            except Exception as e:
                print(f"An error occurred: {e}")

# Run the parallel tests
# run_parallel_tests(people)
