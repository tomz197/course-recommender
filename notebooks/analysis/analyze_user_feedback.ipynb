# %%
from mongo import MongoDBReader

db = MongoDBReader()

# %%
user_feedbacks = db.get_user_feedbacks()

for feedback in user_feedbacks:
    print(feedback)
# Out:
# {'_id': ObjectId('67f9288a9c7ec565c9ecf2e9'), 'text': 'feedback', 'rating': 5, 'faculty': 'fi', 'timestamp': datetime.datetime(2025, 4, 11, 14, 34, 50, 783000)}
# {'_id': ObjectId('67f94f7ca75b75278cd7f4f6'), 'text': None, 'rating': 5, 'faculty': 'FSS', 'timestamp': datetime.datetime(2025, 4, 11, 17, 21, 0, 765000)}

# %%
import matplotlib.pyplot as plt

# Convert cursor to list and extract ratings
ratings = [feedback['rating'] for feedback in db.get_user_feedbacks()]

# Create histogram
plt.figure(figsize=(10, 6))
plt.hist(ratings, bins=range(1, 7), align='left', rwidth=0.8)
plt.title('Distribution of User Feedback Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.xticks(range(1, 6))
plt.grid(True, alpha=0.3)
plt.show()
