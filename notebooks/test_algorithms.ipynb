# %%
import os
import numpy as np
import pandas as pd
import os
import logging

import scripts.helpers as helpers
helpers.add_backend_to_path()

import app.courses as courses

course_client = courses.CourseClient(os.path.join("..", "web", "backend", "assets", "courses"))
df = course_client.df

embeddings_file = os.path.join("data", "embeddings", "embeddings_tomas_03.npy")
#embeddings_file = os.path.join("data", "embeddings", "embeds_from_catalogue.npy")
embeddings = np.load(embeddings_file)

print(embeddings.shape)
print(df.shape)
# Out:
# (21106, 768)
# (21106, 30)

# %%
from IPython.display import display_html

def compare_results(df1, df2, title1="Method 1", title2="Method 2", columns=["CODE", "FACULTY", "NAME"]):
    """
    Display two dataframes side by side with titles for comparison.
    
    Args:
        df1: First dataframe to display
        df2: Second dataframe to display
        title1: Title for the first dataframe
        title2: Title for the second dataframe
        columns: Columns to display from the dataframes
    """
    # Format both DataFrames with styling
    styled_df1 = df1[columns].style.set_properties(**{'text-align': 'left'})
    styled_df2 = df2[columns].style.set_properties(**{'text-align': 'left'})

    # Convert to HTML strings
    html1 = styled_df1._repr_html_()
    html2 = styled_df2._repr_html_()

    # Display side by side with titles
    display_html(
        f'<div style="display: grid; grid-template-columns: 1fr 1fr; width: 100%; gap: 20px;">'
        f'<div>'
        f'<h3>{title1}:</h3>'
        f'{html1}'
        f'</div>'
        f'<div>'
        f'<h3>{title2}:</h3>'
        f'{html2}'
        f'</div>'
        f'</div>',
        raw=True
    )

# %%
# def recommend_mmr(
#   liked_codes: list[str],
#   disliked_codes: list[str],
#   skipped_codes: list[str],
#   all_embeds: np.ndarray,
#   courseClient,
#   n: int = 10,
#   lambda_param: float = 0.7
# ) -> list[dict]:
#   # … same setup as before …
#   liked_indices = courseClient.get_course_ids_by_codes(liked_codes)
#   if not liked_indices:
#     return []
#   liked_avg = np.mean(all_embeds[liked_indices], axis=0)
#   if disliked_codes:
#     disliked_indices = courseClient.get_course_ids_by_codes(disliked_codes)
#     disliked_avg = np.mean(all_embeds[disliked_indices], axis=0)
#     target_embed = liked_avg - 0.5 * disliked_avg
#   else:
#     target_embed = liked_avg

#   # 1) compute raw distances and raw target‐similarities
#   distances = np.linalg.norm(all_embeds - target_embed, axis=1)
#   sim_to_target = 1.0 / (1.0 + distances)

#   excluded = set(liked_codes + disliked_codes + skipped_codes)

#   # 2) build initial candidate list, sorted by descending sim_to_target
#   candidate_idxs = [
#     i for i in np.argsort(-sim_to_target)
#   ][:(max(n, 100) + len(excluded))]

#   excluded_idxs = courseClient.get_course_ids_by_codes(excluded)
#   candidate_idxs = [
#     c for c in candidate_idxs
#     if c not in excluded_idxs
#   ]

#   # 3) MMR re‐ranking loop
#   selected_idxs: list[int] = []
#   while len(selected_idxs) < n and candidate_idxs:
#     # Get current candidate and liked embeddings
#     current_candidate_embeds = all_embeds[candidate_idxs]
#     # liked_embeds can be calculated once outside the loop if liked_indices is static
#     liked_embeds = all_embeds[liked_indices]

#     # 1) Relevance term (vectorized)
#     rel_vector = sim_to_target[candidate_idxs]

#     # 2) Diversity term (vectorized)
#     # Calculate distances between each candidate and all liked embeddings
#     # Shape: (len(candidate_idxs), len(liked_indices))
#     distances_cl = np.linalg.norm(
#         current_candidate_embeds[:, None, :] - liked_embeds[None, :, :],
#         axis=2
#     )
#     # Convert distances to similarities
#     similarities_cl = 1.0 / (1.0 + distances_cl)
#     # Calculate diversity for each candidate (max similarity to any liked item)
#     # Shape: (len(candidate_idxs),)
#     div_vector = np.max(similarities_cl, axis=1)

#     # 3) Calculate MMR scores (vectorized)
#     mmr_scores_vector = lambda_param * rel_vector - (1 - lambda_param) * div_vector

#     # 4) Find the index *within candidate_idxs* corresponding to the max score
#     max_score_local_idx = np.argmax(mmr_scores_vector)

#     # 5) Get the actual course index (ID) with the highest score
#     next_idx = candidate_idxs[max_score_local_idx]

#     # 6) Add the best candidate to selected list and remove from candidates
#     selected_idxs.append(next_idx)
#     candidate_idxs.pop(max_score_local_idx) # More efficient than remove() when we have the index


#   # 4) fetch the courses in the final order
#   recommendations: list[dict] = []
#   for idx in selected_idxs:
#     course = courseClient.get_course_by_id(idx)
#     if course:
#       # you can still store the original distance or sim in an attribute
#       course.SIMILARITY = 1 / (1 + float(distances[idx]))
#       recommendations.append(course)

#   return recommendations

# %%
# def recommend_max(
#   liked_codes: list[str],
#   disliked_codes: list[str],
#   skipped_codes: list[str],
#   all_embeds: np.ndarray,
#   courseClient,
#   n: int = 10,
# ) -> list[dict]:
#   """
#   Most smimilar to any of the liked based on cosine
#   """
#   excluded = set(liked_codes + disliked_codes + skipped_codes)

#   liked_indices = courseClient.get_course_ids_by_codes(liked_codes)
#   disliked_indices = courseClient.get_course_ids_by_codes(disliked_codes)
#   excluded_indices = courseClient.get_course_ids_by_codes(excluded)

#   liked_embeds = all_embeds[liked_indices]
#   disliked_embeds = all_embeds[disliked_indices]

#   # 1. calculate overall similarity
#   candidate_embeds_norm = all_embeds / np.linalg.norm(all_embeds, axis=1, keepdims=True)
#   liked_embeds_norm = liked_embeds / np.linalg.norm(liked_embeds, axis=1, keepdims=True)
#   # Shape: (len(candidate_idxs), len(liked_indices))
#   similarity_liked = np.dot(candidate_embeds_norm, liked_embeds_norm.T)

#   # 2. select best match for each course
#   best_match_liked = np.max(similarity_liked, axis=1)

#   # 3. filter out courses that are too similar
#   if disliked_embeds.shape[0] > 0:
#     disliked_embeds_norm = disliked_embeds / np.linalg.norm(disliked_embeds, axis=1, keepdims=True)
#     similarity_disliked = np.dot(candidate_embeds_norm, disliked_embeds_norm.T)
#     best_match_disliked = np.max(similarity_disliked, axis=1)

#     to_filter_idx = np.where(best_match_disliked > 0.9)[0]
#     best_match_liked[to_filter_idx] = -np.inf

#   # 4. get indices of top n courses
#   selected_idxs = np.argsort(-best_match_liked)[:(n + len(excluded))]
#   selected_idxs = [i for i in selected_idxs if i not in excluded_indices]

#   # 5. fetch the courses in the final order
#   recommendations: list[dict] = []
#   for idx in selected_idxs:
#     course = courseClient.get_course_by_id(idx)
#     if course:
#       # Optionally, attach the similarity score
#       course.SIMILARITY = float(best_match_liked[idx])
#       recommendations.append(course)

#   return recommendations

# %%
from app.recommend.embeddings import recommend_mmr_cos
from app.recommend.baseline import recommend_courses_baseline

LIKED_CODES = []
DISLIKED_CODES = []
SKIPPED_CODES = []

# Baseline can be great in certain situations, e.g. Brazdil - same teaching methods, all are AI courses
LIKED_CODES = ["IB031"]
# But also very bad if:
# - teachers teache a wider spectrum of courses - e.g. IB015
# - you run out of courses taught by that teacher
DISLIKED_CODES = ["PV027", "PV021", "IA168", "IV125", "IV133"]

# BASELINE:
# Not surprising at all, zero serendipity, not very useful
# Overall, not better than just looking up the teacher in IS

rec_mmr = pd.DataFrame(recommend_mmr_cos(
    liked_codes=LIKED_CODES,
    disliked_codes=DISLIKED_CODES,
    skipped_codes=SKIPPED_CODES,
    all_embeds=embeddings,
    courseClient=course_client,
    n=10,
    lambda_param=0.8
))

rec_baseline = pd.DataFrame(recommend_courses_baseline(
    liked=LIKED_CODES,
    disliked=DISLIKED_CODES,
    skipped=SKIPPED_CODES,
    # all_embeds=embeddings,
    courseClient=course_client,
    n=10
))

compare_results(
    rec_mmr, 
    rec_baseline, 
    title1="mmr", 
    title2="baseline",
    columns=["CODE", "FACULTY", "NAME", "TEACHERS", "DEPARTMENT"]
)
# Out:
# <div style="display: grid; grid-template-columns: 1fr 1fr; width: 100%; gap: 20px;"><div><h3>mmr:</h3><style type="text/css">
# #T_f45a0_row0_col0, #T_f45a0_row0_col1, #T_f45a0_row0_col2, #T_f45a0_row0_col3, #T_f45a0_row0_col4, #T_f45a0_row1_col0, #T_f45a0_row1_col1, #T_f45a0_row1_col2, #T_f45a0_row1_col3, #T_f45a0_row1_col4, #T_f45a0_row2_col0, #T_f45a0_row2_col1, #T_f45a0_row2_col2, #T_f45a0_row2_col3, #T_f45a0_row2_col4, #T_f45a0_row3_col0, #T_f45a0_row3_col1, #T_f45a0_row3_col2, #T_f45a0_row3_col3, #T_f45a0_row3_col4, #T_f45a0_row4_col0, #T_f45a0_row4_col1, #T_f45a0_row4_col2, #T_f45a0_row4_col3, #T_f45a0_row4_col4, #T_f45a0_row5_col0, #T_f45a0_row5_col1, #T_f45a0_row5_col2, #T_f45a0_row5_col3, #T_f45a0_row5_col4, #T_f45a0_row6_col0, #T_f45a0_row6_col1, #T_f45a0_row6_col2, #T_f45a0_row6_col3, #T_f45a0_row6_col4, #T_f45a0_row7_col0, #T_f45a0_row7_col1, #T_f45a0_row7_col2, #T_f45a0_row7_col3, #T_f45a0_row7_col4, #T_f45a0_row8_col0, #T_f45a0_row8_col1, #T_f45a0_row8_col2, #T_f45a0_row8_col3, #T_f45a0_row8_col4, #T_f45a0_row9_col0, #T_f45a0_row9_col1, #T_f45a0_row9_col2, #T_f45a0_row9_col3, #T_f45a0_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_f45a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f45a0_level0_col0" class="col_heading level0 col0" >CODE</th>
#       <th id="T_f45a0_level0_col1" class="col_heading level0 col1" >FACULTY</th>
#       <th id="T_f45a0_level0_col2" class="col_heading level0 col2" >NAME</th>
#       <th id="T_f45a0_level0_col3" class="col_heading level0 col3" >TEACHERS</th>
#       <th id="T_f45a0_level0_col4" class="col_heading level0 col4" >DEPARTMENT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f45a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f45a0_row0_col0" class="data row0 col0" >MKF_AIIF</td>
#       <td id="T_f45a0_row0_col1" class="data row0 col1" >ESF</td>
#       <td id="T_f45a0_row0_col2" class="data row0 col2" > AI in Finance </td>
#       <td id="T_f45a0_row0_col3" class="data row0 col3" >Lyócsa, Š.</td>
#       <td id="T_f45a0_row0_col4" class="data row0 col4" >KFin</td>
#     </tr>
#     <tr>
#       <th id="T_f45a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f45a0_row1_col0" class="data row1 col0" >MPF_AIIF</td>
#       <td id="T_f45a0_row1_col1" class="data row1 col1" >ESF</td>
#       <td id="T_f45a0_row1_col2" class="data row1 col2" > AI in Finance </td>
#       <td id="T_f45a0_row1_col3" class="data row1 col3" >Lyócsa, Š. - Lyócsa, Š. - Vondráček, D.</td>
#       <td id="T_f45a0_row1_col4" class="data row1 col4" >KFin</td>
#     </tr>
#     <tr>
#       <th id="T_f45a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f45a0_row2_col0" class="data row2 col0" >Bi9680en</td>
#       <td id="T_f45a0_row2_col1" class="data row2 col1" >PřF</td>
#       <td id="T_f45a0_row2_col2" class="data row2 col2" > Artificial Intelligence in Biology, Chemistry, and Bioengineering </td>
#       <td id="T_f45a0_row2_col3" class="data row2 col3" >Damborský, J. - Mazurenko, S. - Haddadi, F. - Kohout, P. - Velecký, J.</td>
#       <td id="T_f45a0_row2_col4" class="data row2 col4" >ÚEB</td>
#     </tr>
#     <tr>
#       <th id="T_f45a0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f45a0_row3_col0" class="data row3 col0" >E0034</td>
#       <td id="T_f45a0_row3_col1" class="data row3 col1" >PřF</td>
#       <td id="T_f45a0_row3_col2" class="data row3 col2" > Analýza a klasifikace dat </td>
#       <td id="T_f45a0_row3_col3" class="data row3 col3" >Koriťáková, E. - Holčík, J. - Vyškovský, R. - Jurková, T.</td>
#       <td id="T_f45a0_row3_col4" class="data row3 col4" >RECETOX</td>
#     </tr>
#     <tr>
#       <th id="T_f45a0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f45a0_row4_col0" class="data row4 col0" >PA164</td>
#       <td id="T_f45a0_row4_col1" class="data row4 col1" >FI</td>
#       <td id="T_f45a0_row4_col2" class="data row4 col2" >Machine learning and natural language processing</td>
#       <td id="T_f45a0_row4_col3" class="data row4 col3" >Nováček, V.</td>
#       <td id="T_f45a0_row4_col4" class="data row4 col4" >KSUZD</td>
#     </tr>
#     <tr>
#       <th id="T_f45a0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f45a0_row5_col0" class="data row5 col0" >M8DM1</td>
#       <td id="T_f45a0_row5_col1" class="data row5 col1" >PřF</td>
#       <td id="T_f45a0_row5_col2" class="data row5 col2" > Data mining I </td>
#       <td id="T_f45a0_row5_col3" class="data row5 col3" >Navrátil, R.</td>
#       <td id="T_f45a0_row5_col4" class="data row5 col4" >ÚMS</td>
#     </tr>
#     <tr>
#       <th id="T_f45a0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f45a0_row6_col0" class="data row6 col0" >PV115</td>
#       <td id="T_f45a0_row6_col1" class="data row6 col1" >FI</td>
#       <td id="T_f45a0_row6_col2" class="data row6 col2" >Laboratoř dobývání znalostí</td>
#       <td id="T_f45a0_row6_col3" class="data row6 col3" >Popelínský, L.</td>
#       <td id="T_f45a0_row6_col4" class="data row6 col4" >KSUZD</td>
#     </tr>
#     <tr>
#       <th id="T_f45a0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f45a0_row7_col0" class="data row7 col0" >E7490</td>
#       <td id="T_f45a0_row7_col1" class="data row7 col1" >PřF</td>
#       <td id="T_f45a0_row7_col2" class="data row7 col2" > Pokročilé neparametrické metody </td>
#       <td id="T_f45a0_row7_col3" class="data row7 col3" >Komprdová, K.</td>
#       <td id="T_f45a0_row7_col4" class="data row7 col4" >RECETOX</td>
#     </tr>
#     <tr>
#       <th id="T_f45a0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f45a0_row8_col0" class="data row8 col0" >PV211</td>
#       <td id="T_f45a0_row8_col1" class="data row8 col1" >FI</td>
#       <td id="T_f45a0_row8_col2" class="data row8 col2" >Introduction to Information Retrieval</td>
#       <td id="T_f45a0_row8_col3" class="data row8 col3" >Sojka, P. - Fajčík, M. - Vrabcová, T. - Ščavnická, Š. - Štefánik, M. - Toma, M. - Starý Novotný, V.</td>
#       <td id="T_f45a0_row8_col4" class="data row8 col4" >KVI</td>
#     </tr>
#     <tr>
#       <th id="T_f45a0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f45a0_row9_col0" class="data row9 col0" >dc4004</td>
#       <td id="T_f45a0_row9_col1" class="data row9 col1" >FSpS</td>
#       <td id="T_f45a0_row9_col2" class="data row9 col2" > Aplikovaná matematická statistika </td>
#       <td id="T_f45a0_row9_col3" class="data row9 col3" >Sebera, M.</td>
#       <td id="T_f45a0_row9_col4" class="data row9 col4" >HEALTH</td>
#     </tr>
#   </tbody>
# </table>
# </div><div><h3>baseline:</h3><style type="text/css">
# #T_8c19e_row0_col0, #T_8c19e_row0_col1, #T_8c19e_row0_col2, #T_8c19e_row0_col3, #T_8c19e_row0_col4, #T_8c19e_row1_col0, #T_8c19e_row1_col1, #T_8c19e_row1_col2, #T_8c19e_row1_col3, #T_8c19e_row1_col4, #T_8c19e_row2_col0, #T_8c19e_row2_col1, #T_8c19e_row2_col2, #T_8c19e_row2_col3, #T_8c19e_row2_col4, #T_8c19e_row3_col0, #T_8c19e_row3_col1, #T_8c19e_row3_col2, #T_8c19e_row3_col3, #T_8c19e_row3_col4, #T_8c19e_row4_col0, #T_8c19e_row4_col1, #T_8c19e_row4_col2, #T_8c19e_row4_col3, #T_8c19e_row4_col4, #T_8c19e_row5_col0, #T_8c19e_row5_col1, #T_8c19e_row5_col2, #T_8c19e_row5_col3, #T_8c19e_row5_col4, #T_8c19e_row6_col0, #T_8c19e_row6_col1, #T_8c19e_row6_col2, #T_8c19e_row6_col3, #T_8c19e_row6_col4, #T_8c19e_row7_col0, #T_8c19e_row7_col1, #T_8c19e_row7_col2, #T_8c19e_row7_col3, #T_8c19e_row7_col4, #T_8c19e_row8_col0, #T_8c19e_row8_col1, #T_8c19e_row8_col2, #T_8c19e_row8_col3, #T_8c19e_row8_col4, #T_8c19e_row9_col0, #T_8c19e_row9_col1, #T_8c19e_row9_col2, #T_8c19e_row9_col3, #T_8c19e_row9_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_8c19e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c19e_level0_col0" class="col_heading level0 col0" >CODE</th>
#       <th id="T_8c19e_level0_col1" class="col_heading level0 col1" >FACULTY</th>
#       <th id="T_8c19e_level0_col2" class="col_heading level0 col2" >NAME</th>
#       <th id="T_8c1

# %%
if not LIKED_CODES:
    LIKED_CODES = ["MV008"] # crashes if empty
if not DISLIKED_CODES:
    DISLIKED_CODES = ["PB007"] # crashes if empty

liked_courses_with_scores = pd.DataFrame([course_client.get_course_by_code(code) for code in LIKED_CODES])
disliked_courses_with_scores = pd.DataFrame([course_client.get_course_by_code(code) for code in DISLIKED_CODES])

compare_results(
    liked_courses_with_scores, 
    disliked_courses_with_scores, 
    title1="liked", 
    title2="disliked",
    columns=["CODE", "FACULTY", "NAME", "TEACHERS", "DEPARTMENT"]
)
# Out:
# <div style="display: grid; grid-template-columns: 1fr 1fr; width: 100%; gap: 20px;"><div><h3>liked:</h3><style type="text/css">
# #T_4f2fa_row0_col0, #T_4f2fa_row0_col1, #T_4f2fa_row0_col2, #T_4f2fa_row0_col3, #T_4f2fa_row0_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_4f2fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f2fa_level0_col0" class="col_heading level0 col0" >CODE</th>
#       <th id="T_4f2fa_level0_col1" class="col_heading level0 col1" >FACULTY</th>
#       <th id="T_4f2fa_level0_col2" class="col_heading level0 col2" >NAME</th>
#       <th id="T_4f2fa_level0_col3" class="col_heading level0 col3" >TEACHERS</th>
#       <th id="T_4f2fa_level0_col4" class="col_heading level0 col4" >DEPARTMENT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f2fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f2fa_row0_col0" class="data row0 col0" >IB031</td>
#       <td id="T_4f2fa_row0_col1" class="data row0 col1" >FI</td>
#       <td id="T_4f2fa_row0_col2" class="data row0 col2" >Úvod do strojového učení</td>
#       <td id="T_4f2fa_row0_col3" class="data row0 col3" >Brázdil, T. - Čechák, J. - Čechová, M. - Foltýnek, T. - Gregora, F. - Kecskésová, M. - Nováček, V. - Pavlík, T. - Wernerová, P.</td>
#       <td id="T_4f2fa_row0_col4" class="data row0 col4" >KSUZD</td>
#     </tr>
#   </tbody>
# </table>
# </div><div><h3>disliked:</h3><style type="text/css">
# #T_4593d_row0_col0, #T_4593d_row0_col1, #T_4593d_row0_col2, #T_4593d_row0_col3, #T_4593d_row0_col4, #T_4593d_row1_col0, #T_4593d_row1_col1, #T_4593d_row1_col2, #T_4593d_row1_col3, #T_4593d_row1_col4, #T_4593d_row2_col0, #T_4593d_row2_col1, #T_4593d_row2_col2, #T_4593d_row2_col3, #T_4593d_row2_col4, #T_4593d_row3_col0, #T_4593d_row3_col1, #T_4593d_row3_col2, #T_4593d_row3_col3, #T_4593d_row3_col4, #T_4593d_row4_col0, #T_4593d_row4_col1, #T_4593d_row4_col2, #T_4593d_row4_col3, #T_4593d_row4_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_4593d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4593d_level0_col0" class="col_heading level0 col0" >CODE</th>
#       <th id="T_4593d_level0_col1" class="col_heading level0 col1" >FACULTY</th>
#       <th id="T_4593d_level0_col2" class="col_heading level0 col2" >NAME</th>
#       <th id="T_4593d_level0_col3" class="col_heading level0 col3" >TEACHERS</th>
#       <th id="T_4593d_level0_col4" class="col_heading level0 col4" >DEPARTMENT</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4593d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4593d_row0_col0" class="data row0 col0" >PV027</td>
#       <td id="T_4593d_row0_col1" class="data row0 col1" >FI</td>
#       <td id="T_4593d_row0_col2" class="data row0 col2" >Optimization</td>
#       <td id="T_4593d_row0_col3" class="data row0 col3" >Brázdil, T. - Musil, V. - Kurečka, M.</td>
#       <td id="T_4593d_row0_col4" class="data row0 col4" >KSUZD</td>
#     </tr>
#     <tr>
#       <th id="T_4593d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4593d_row1_col0" class="data row1 col0" >PV021</td>
#       <td id="T_4593d_row1_col1" class="data row1 col1" >FI</td>
#       <td id="T_4593d_row1_col2" class="data row1 col2" >Neural Networks</td>
#       <td id="T_4593d_row1_col3" class="data row1 col3" >Brázdil, T. - Foltýnek, T. - Gallo, M. - Bajger, A. - Ivora, A. - Zelina, P. - Kubín, J. - Kraus, J. - Lejdar, L. - Šimurka, A.</td>
#       <td id="T_4593d_row1_col4" class="data row1 col4" >KSUZD</td>
#     </tr>
#     <tr>
#       <th id="T_4593d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4593d_row2_col0" class="data row2 col0" >IA168</td>
#       <td id="T_4593d_row2_col1" class="data row2 col1" >FI</td>
#       <td id="T_4593d_row2_col2" class="data row2 col2" >Algorithmic game theory</td>
#       <td id="T_4593d_row2_col3" class="data row2 col3" >Brázdil, T. - Balabán, J. - Klaška, D. - Kurečka, M. - Žáček, M.</td>
#       <td id="T_4593d_row2_col4" class="data row2 col4" >KSUZD</td>
#     </tr>
#     <tr>
#       <th id="T_4593d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4593d_row3_col0" class="data row3 col0" >IV125</td>
#       <td id="T_4593d_row3_col1" class="data row3 col1" >FI</td>
#       <td id="T_4593d_row3_col2" class="data row3 col2" >Formela lab seminar</td>
#       <td id="T_4593d_row3_col3" class="data row3 col3" >Kučera, A. - Brázdil, T. - Řehák, V. - Blumensath, A. - Obdržálek, J. - Novotný, P. - Jonáš, M. - Musil, V. - Klaška, D. - Anselm Paulus</td>
#       <td id="T_4593d_row3_col4" class="data row3 col4" >KTP</td>
#     </tr>
#     <tr>
#       <th id="T_4593d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4593d_row4_col0" class="data row4 col0" >IV133</td>
#       <td id="T_4593d_row4_col1" class="data row4 col1" >FI</td>
#       <td id="T_4593d_row4_col2" class="data row4 col2" >Seminář laboratoře RationAI</td>
#       <td id="T_4593d_row4_col3" class="data row4 col3" >Brázdil, T. - Musil, V.</td>
#       <td id="T_4593d_row4_col4" class="data row4 col4" >KTP</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
import app.recommend.embeddings as rec_embeddings
import importlib
importlib.reload(rec_embeddings)

LIKED_CODES = []
DISLIKED_CODES = []
SKIPPED_CODES = []

# LIKED_CODES = ["IB015", "IB016", "IB002", "MB152", "AEB_A14b", "DUCIT", "p952"] # Tereza
# LIKED_CODES = ["C7073", "Bi4010", "IB111"] # bioinformatics
# LIKED_CODES = ["BIp001", "IB002", "IB005"] # bioinformatics
# DISLIKED_CODES = ["IB000", "PV080"]
# LIKED_CODES = ["IB005", "MA010", "IA159", "PV021", "IB031"]
# LIKED_CODES = ["IB031", "CORE016"]
# LIKED_CODES = ["IV124", "IB031"]
LIKED_CODES = ["PV021", "NLI_04"]
DISLIKED_CODES = []

# LIKED_CODES = ['IB111', "MV008", "IB031"]
# DISLIKED_CODES = ["PB007"]

rec_mmr = pd.DataFrame(rec_embeddings.recommend_mmr_cos(
    liked_codes=LIKED_CODES,
    disliked_codes=DISLIKED_CODES,
    skipped_codes=SKIPPED_CODES,
    all_embeds=embeddings,
    courseClient=course_client,
    n=30,
    lambda_param=0.8
))

rec_baseline = pd.DataFrame(rec_embeddings.recommend_max_with_combinations(
    liked_codes=LIKED_CODES,
    disliked_codes=DISLIKED_CODES,
    skipped_codes=SKIPPED_CODES,
    all_embeds=embeddings,
    courseClient=course_client,
    n=30,
    # lambda_param=0.8
))

compare_results(
    rec_mmr, 
    rec_baseline, 
    title1="mmr", 
    title2="max",
    columns=["CODE", "FACULTY", "NAME", "RECOMMENDED_FROM", "SIMILARITY"]
)
# Out:
# <div style="display: grid; grid-template-columns: 1fr 1fr; width: 100%; gap: 20px;"><div><h3>mmr:</h3><style type="text/css">
# #T_b9424_row0_col0, #T_b9424_row0_col1, #T_b9424_row0_col2, #T_b9424_row0_col3, #T_b9424_row0_col4, #T_b9424_row1_col0, #T_b9424_row1_col1, #T_b9424_row1_col2, #T_b9424_row1_col3, #T_b9424_row1_col4, #T_b9424_row2_col0, #T_b9424_row2_col1, #T_b9424_row2_col2, #T_b9424_row2_col3, #T_b9424_row2_col4, #T_b9424_row3_col0, #T_b9424_row3_col1, #T_b9424_row3_col2, #T_b9424_row3_col3, #T_b9424_row3_col4, #T_b9424_row4_col0, #T_b9424_row4_col1, #T_b9424_row4_col2, #T_b9424_row4_col3, #T_b9424_row4_col4, #T_b9424_row5_col0, #T_b9424_row5_col1, #T_b9424_row5_col2, #T_b9424_row5_col3, #T_b9424_row5_col4, #T_b9424_row6_col0, #T_b9424_row6_col1, #T_b9424_row6_col2, #T_b9424_row6_col3, #T_b9424_row6_col4, #T_b9424_row7_col0, #T_b9424_row7_col1, #T_b9424_row7_col2, #T_b9424_row7_col3, #T_b9424_row7_col4, #T_b9424_row8_col0, #T_b9424_row8_col1, #T_b9424_row8_col2, #T_b9424_row8_col3, #T_b9424_row8_col4, #T_b9424_row9_col0, #T_b9424_row9_col1, #T_b9424_row9_col2, #T_b9424_row9_col3, #T_b9424_row9_col4, #T_b9424_row10_col0, #T_b9424_row10_col1, #T_b9424_row10_col2, #T_b9424_row10_col3, #T_b9424_row10_col4, #T_b9424_row11_col0, #T_b9424_row11_col1, #T_b9424_row11_col2, #T_b9424_row11_col3, #T_b9424_row11_col4, #T_b9424_row12_col0, #T_b9424_row12_col1, #T_b9424_row12_col2, #T_b9424_row12_col3, #T_b9424_row12_col4, #T_b9424_row13_col0, #T_b9424_row13_col1, #T_b9424_row13_col2, #T_b9424_row13_col3, #T_b9424_row13_col4, #T_b9424_row14_col0, #T_b9424_row14_col1, #T_b9424_row14_col2, #T_b9424_row14_col3, #T_b9424_row14_col4, #T_b9424_row15_col0, #T_b9424_row15_col1, #T_b9424_row15_col2, #T_b9424_row15_col3, #T_b9424_row15_col4, #T_b9424_row16_col0, #T_b9424_row16_col1, #T_b9424_row16_col2, #T_b9424_row16_col3, #T_b9424_row16_col4, #T_b9424_row17_col0, #T_b9424_row17_col1, #T_b9424_row17_col2, #T_b9424_row17_col3, #T_b9424_row17_col4, #T_b9424_row18_col0, #T_b9424_row18_col1, #T_b9424_row18_col2, #T_b9424_row18_col3, #T_b9424_row18_col4, #T_b9424_row19_col0, #T_b9424_row19_col1, #T_b9424_row19_col2, #T_b9424_row19_col3, #T_b9424_row19_col4, #T_b9424_row20_col0, #T_b9424_row20_col1, #T_b9424_row20_col2, #T_b9424_row20_col3, #T_b9424_row20_col4, #T_b9424_row21_col0, #T_b9424_row21_col1, #T_b9424_row21_col2, #T_b9424_row21_col3, #T_b9424_row21_col4, #T_b9424_row22_col0, #T_b9424_row22_col1, #T_b9424_row22_col2, #T_b9424_row22_col3, #T_b9424_row22_col4, #T_b9424_row23_col0, #T_b9424_row23_col1, #T_b9424_row23_col2, #T_b9424_row23_col3, #T_b9424_row23_col4, #T_b9424_row24_col0, #T_b9424_row24_col1, #T_b9424_row24_col2, #T_b9424_row24_col3, #T_b9424_row24_col4, #T_b9424_row25_col0, #T_b9424_row25_col1, #T_b9424_row25_col2, #T_b9424_row25_col3, #T_b9424_row25_col4, #T_b9424_row26_col0, #T_b9424_row26_col1, #T_b9424_row26_col2, #T_b9424_row26_col3, #T_b9424_row26_col4, #T_b9424_row27_col0, #T_b9424_row27_col1, #T_b9424_row27_col2, #T_b9424_row27_col3, #T_b9424_row27_col4, #T_b9424_row28_col0, #T_b9424_row28_col1, #T_b9424_row28_col2, #T_b9424_row28_col3, #T_b9424_row28_col4, #T_b9424_row29_col0, #T_b9424_row29_col1, #T_b9424_row29_col2, #T_b9424_row29_col3, #T_b9424_row29_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_b9424">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9424_level0_col0" class="col_heading level0 col0" >CODE</th>
#       <th id="T_b9424_level0_col1" class="col_heading level0 col1" >FACULTY</th>
#       <th id="T_b9424_level0_col2" class="col_heading level0 col2" >NAME</th>
#       <th id="T_b9424_level0_col3" class="col_heading level0 col3" >RECOMMENDED_FROM</th>
#       <th id="T_b9424_level0_col4" class="col_heading level0 col4" >SIMILARITY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9424_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9424_row0_col0" class="data row0 col0" >IB030</td>
#       <td id="T_b9424_row0_col1" class="data row0 col1" >FI</td>
#       <td id="T_b9424_row0_col2" class="data row0 col2" >Úvod do počítačového zpracování přirozeného jazyka</td>
#       <td id="T_b9424_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_b9424_row0_col4" class="data row0 col4" >0.860800</td>
#     </tr>
#     <tr>
#       <th id="T_b9424_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b9424_row1_col0" class="data row1 col0" >PV061</td>
#       <td id="T_b9424_row1_col1" class="data row1 col1" >FI</td>
#       <td id="T_b9424_row1_col2" class="data row1 col2" >Machine Translation</td>
#       <td id="T_b9424_row1_col3" class="data row1 col3" >None</td>
#       <td id="T_b9424_row1_col4" class="data row1 col4" >0.851048</td>
#     </tr>
#     <tr>
#       <th id="T_b9424_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b9424_row2_col0" class="data row2 col0" >MED02</td>
#       <td id="T_b9424_row2_col1" class="data row2 col1" >FF</td>
#       <td id="T_b9424_row2_col2" class="data row2 col2" > Úvod do jazykovědy </td>
#       <td id="T_b9424_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_b9424_row2_col4" class="data row2 col4" >0.867861</td>
#     </tr>
#     <tr>
#       <th id="T_b9424_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b9424_row3_col0" class="data row3 col0" >PLIN059</td>
#       <td id="T_b9424_row3_col1" class="data row3 col1" >FF</td>
#       <td id="T_b9424_row3_col2" class="data row3 col2" > Proseminář z počítačové lingvistiky </td>
#       <td id="T_b9424_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_b9424_row3_col4" class="data row3 col4" >0.846078</td>
#     </tr>
#     <tr>
#       <th id="T_b9424_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b9424_row4_col0" class="data row4 col0" >PLIN034</td>
#       <td id="T_b9424_row4_col1" class="data row4 col1" >FF</td>
#       <td id="T_b9424_row4_col2" class="data row4 col2" > Algoritmický popis syntaxe </td>
#       <td id="T_b9424_row4_col3" class="data row4 col3" >None</td>
#       <td id="T_b9424_row4_col4" class="data row4 col4" >0.842996</td>
#     </tr>
#     <tr>
#       <th id="T_b9424_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b9424_row5_col0" class="data row5 col0" >PSMA013</td>
#       <td id="T_b9424_row5_col1" class="data row5 col1" >FF</td>
#       <td id="T_b9424_row5_col2" class="data row5 col2" > Klinická neuropsychologie </td>
#       <td id="T_b9424_row5_col3" class="data row5 col3" >None</td>
#       <td id="T_b9424_row5_col4" class="data row5 col4" >0.830327</td>
#     </tr>
#     <tr>
#       <th id="T_b9424_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b9424_row6_col0" class="data row6 col0" >PSBA026</td>
#       <td id="T_b9424_row6_col1" class="data row6 col1" >FF</td>
#       <td id="T_b9424_row6_col2" class="data row6 col2" > Základy neuropsychologie </td>
#       <td id="T_b9424_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_b9424_row6_col4" class="data row6 col4" >0.831396</td>
#     </tr>
#     <tr>
#       <th id="T_b9424_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b9424_row7_col0" class="data row7 col0" >PA153</td>
#       <td id="T_b9424_row7_col1" class="data row7 col1" >FI</td>
#       <td id="T_b9424_row7_col2" class="data row7 col2" >Natural Language Processing</td>
#       <td id="T_b9424_row7_col3" class="data row7 col3" >None</td>
#       <td id="T_b9424_row7_col4" class="data row7 col4" >0.838346</td>
#     </tr>
#     <tr>
#       <th id="T_b9424_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b9424_row8_col0" class="data row8 col0" >ISKM31</td>
#       <td id="T_b9424_row8_col1" class="data row8 col1" >FF</td>
#       <td id="T_b9424_row8_col2" class="data row8 col2" > Vzdělávací technologie </td>
#       <td id="T_b9424_row8_col3" class="data row8 col3" >None</td>
#       <td id="T_b9424_row8_col4" class="data row8 col4" >0.829139</td>
#     </tr>
#     <tr>
#       <th id="T_b9424_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id=

# %%
# Compare embeddings

from app.recommend.embeddings import recommend_average

embeddings_1 = np.load(os.path.join("data", "embeddings", "embeddings_tomas_03.npy"))
embeddings_2 = np.load(os.path.join("data", "embeddings", "embeds_from_catalogue.npy"))

LIKED_CODES = ["PV197", "IB031", "CORE047"] # base
DISLIKED_CODES = ["MB151", "MB152", "MB154"] # base
#LIKED_CODES = ["C7073", "Bi4010", "IB002"] # bioinformatics
#LIKED_CODES = ["IB111"]
SKIPPED_CODES = []

LIKED_CODES = ["PV197", "IB031", "CORE047", "RLB666"]
DISLIKED_CODES = ["MB151", "MB152", "MB154"]
SKIPPED_CODES = []

rec_avg_1 = pd.DataFrame(recommend_average(
    liked_codes=LIKED_CODES,
    disliked_codes=DISLIKED_CODES,
    skipped_codes=SKIPPED_CODES,
    all_embeds=embeddings_1,
    courseClient=course_client,
    n=10
))

rec_avg_2 = pd.DataFrame(recommend_average(
    liked_codes=LIKED_CODES,
    disliked_codes=DISLIKED_CODES,
    skipped_codes=SKIPPED_CODES,
    all_embeds=embeddings_2,
    courseClient=course_client,
    n=10   
))

compare_results(
    rec_avg_1,  
    rec_avg_2,
    title1="Embeddings 03",
    title2="Embeddings base"
)
# Out:
# <div style="display: grid; grid-template-columns: 1fr 1fr; width: 100%; gap: 20px;"><div><h3>Embeddings 03:</h3><style type="text/css">
# #T_062d5_row0_col0, #T_062d5_row0_col1, #T_062d5_row0_col2, #T_062d5_row1_col0, #T_062d5_row1_col1, #T_062d5_row1_col2, #T_062d5_row2_col0, #T_062d5_row2_col1, #T_062d5_row2_col2, #T_062d5_row3_col0, #T_062d5_row3_col1, #T_062d5_row3_col2, #T_062d5_row4_col0, #T_062d5_row4_col1, #T_062d5_row4_col2, #T_062d5_row5_col0, #T_062d5_row5_col1, #T_062d5_row5_col2, #T_062d5_row6_col0, #T_062d5_row6_col1, #T_062d5_row6_col2, #T_062d5_row7_col0, #T_062d5_row7_col1, #T_062d5_row7_col2, #T_062d5_row8_col0, #T_062d5_row8_col1, #T_062d5_row8_col2, #T_062d5_row9_col0, #T_062d5_row9_col1, #T_062d5_row9_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_062d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_062d5_level0_col0" class="col_heading level0 col0" >CODE</th>
#       <th id="T_062d5_level0_col1" class="col_heading level0 col1" >FACULTY</th>
#       <th id="T_062d5_level0_col2" class="col_heading level0 col2" >NAME</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_062d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_062d5_row0_col0" class="data row0 col0" >PV242</td>
#       <td id="T_062d5_row0_col1" class="data row0 col1" >FI</td>
#       <td id="T_062d5_row0_col2" class="data row0 col2" >Inovace a podnikání</td>
#     </tr>
#     <tr>
#       <th id="T_062d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_062d5_row1_col0" class="data row1 col0" >XV004</td>
#       <td id="T_062d5_row1_col1" class="data row1 col1" >PřF</td>
#       <td id="T_062d5_row1_col2" class="data row1 col2" > Od nápadu k podnikání </td>
#     </tr>
#     <tr>
#       <th id="T_062d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_062d5_row2_col0" class="data row2 col0" >MKH_PODN</td>
#       <td id="T_062d5_row2_col1" class="data row2 col1" >ESF</td>
#       <td id="T_062d5_row2_col2" class="data row2 col2" >Business</td>
#     </tr>
#     <tr>
#       <th id="T_062d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_062d5_row3_col0" class="data row3 col0" >MPH_PODN</td>
#       <td id="T_062d5_row3_col1" class="data row3 col1" >ESF</td>
#       <td id="T_062d5_row3_col2" class="data row3 col2" > Podnikání </td>
#     </tr>
#     <tr>
#       <th id="T_062d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_062d5_row4_col0" class="data row4 col0" >BKH_ZAPO</td>
#       <td id="T_062d5_row4_col1" class="data row4 col1" >ESF</td>
#       <td id="T_062d5_row4_col2" class="data row4 col2" > Základy podnikání </td>
#     </tr>
#     <tr>
#       <th id="T_062d5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_062d5_row5_col0" class="data row5 col0" >BPH_ZAPO</td>
#       <td id="T_062d5_row5_col1" class="data row5 col1" >ESF</td>
#       <td id="T_062d5_row5_col2" class="data row5 col2" > Základy podnikání </td>
#     </tr>
#     <tr>
#       <th id="T_062d5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_062d5_row6_col0" class="data row6 col0" >BKF_TEZP</td>
#       <td id="T_062d5_row6_col1" class="data row6 col1" >ESF</td>
#       <td id="T_062d5_row6_col2" class="data row6 col2" > Teze závěrečné práce </td>
#     </tr>
#     <tr>
#       <th id="T_062d5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_062d5_row7_col0" class="data row7 col0" >BPE_TEBP</td>
#       <td id="T_062d5_row7_col1" class="data row7 col1" >ESF</td>
#       <td id="T_062d5_row7_col2" class="data row7 col2" > Teze bakalářské práce </td>
#     </tr>
#     <tr>
#       <th id="T_062d5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_062d5_row8_col0" class="data row8 col0" >BPH_BAS2</td>
#       <td id="T_062d5_row8_col1" class="data row8 col1" >ESF</td>
#       <td id="T_062d5_row8_col2" class="data row8 col2" > Bakalářský seminář 2 </td>
#     </tr>
#     <tr>
#       <th id="T_062d5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_062d5_row9_col0" class="data row9 col0" >BPF_TEBP</td>
#       <td id="T_062d5_row9_col1" class="data row9 col1" >ESF</td>
#       <td id="T_062d5_row9_col2" class="data row9 col2" > Teze bakalářské práce </td>
#     </tr>
#   </tbody>
# </table>
# </div><div><h3>Embeddings base:</h3><style type="text/css">
# #T_59efa_row0_col0, #T_59efa_row0_col1, #T_59efa_row0_col2, #T_59efa_row1_col0, #T_59efa_row1_col1, #T_59efa_row1_col2, #T_59efa_row2_col0, #T_59efa_row2_col1, #T_59efa_row2_col2, #T_59efa_row3_col0, #T_59efa_row3_col1, #T_59efa_row3_col2, #T_59efa_row4_col0, #T_59efa_row4_col1, #T_59efa_row4_col2, #T_59efa_row5_col0, #T_59efa_row5_col1, #T_59efa_row5_col2, #T_59efa_row6_col0, #T_59efa_row6_col1, #T_59efa_row6_col2, #T_59efa_row7_col0, #T_59efa_row7_col1, #T_59efa_row7_col2, #T_59efa_row8_col0, #T_59efa_row8_col1, #T_59efa_row8_col2, #T_59efa_row9_col0, #T_59efa_row9_col1, #T_59efa_row9_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_59efa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59efa_level0_col0" class="col_heading level0 col0" >CODE</th>
#       <th id="T_59efa_level0_col1" class="col_heading level0 col1" >FACULTY</th>
#       <th id="T_59efa_level0_col2" class="col_heading level0 col2" >NAME</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59efa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59efa_row0_col0" class="data row0 col0" >XV004</td>
#       <td id="T_59efa_row0_col1" class="data row0 col1" >PřF</td>
#       <td id="T_59efa_row0_col2" class="data row0 col2" > Od nápadu k podnikání </td>
#     </tr>
#     <tr>
#       <th id="T_59efa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_59efa_row1_col0" class="data row1 col0" >SLAV01</td>
#       <td id="T_59efa_row1_col1" class="data row1 col1" >FF</td>
#       <td id="T_59efa_row1_col2" class="data row1 col2" > Seminář k magisterské diplomové práci I </td>
#     </tr>
#     <tr>
#       <th id="T_59efa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_59efa_row2_col0" class="data row2 col0" >SLAV01S</td>
#       <td id="T_59efa_row2_col1" class="data row2 col1" >FF</td>
#       <td id="T_59efa_row2_col2" class="data row2 col2" > Seminář k magisterské diplomové práci I </td>
#     </tr>
#     <tr>
#       <th id="T_59efa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_59efa_row3_col0" class="data row3 col0" >PV242</td>
#       <td id="T_59efa_row3_col1" class="data row3 col1" >FI</td>
#       <td id="T_59efa_row3_col2" class="data row3 col2" >Inovace a podnikání</td>
#     </tr>
#     <tr>
#       <th id="T_59efa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_59efa_row4_col0" class="data row4 col0" >BPF_TEBP</td>
#       <td id="T_59efa_row4_col1" class="data row4 col1" >ESF</td>
#       <td id="T_59efa_row4_col2" class="data row4 col2" > Teze bakalářské práce </td>
#     </tr>
#     <tr>
#       <th id="T_59efa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_59efa_row5_col0" class="data row5 col0" >BPE_TEBP</td>
#       <td id="T_59efa_row5_col1" class="data row5 col1" >ESF</td>
#       <td id="T_59efa_row5_col2" class="data row5 col2" > Teze bakalářské práce </td>
#     </tr>
#     <tr>
#       <th id="T_59efa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_59efa_row6_col0" class="data row6 col0" >SLAV02</td>
#       <td id="T_59efa_row6_col1" class="data row6 col1" >FF</td>
#       <td id="T_59efa_row6_col2" class="data row6 col2" > Seminář k magisterské diplomové práci II </td>
#     </tr>
#     <tr>
#       <th id="T_59efa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_59efa_row7_col0" class="data row7 col0" >BKF_TEZP</td>
#       <td id="T_59efa_row7_col1" class="data row7 col1" >ESF</td>
#       <td id="T_59efa_row7_col2" class="data row7 col2" > Teze závěrečné práce </td>
#     </tr>
#     <tr>
#       <th id="T_59efa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_59efa_row8_col0" class=
